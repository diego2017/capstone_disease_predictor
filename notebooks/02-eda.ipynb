# %% [markdown]
# <div id="container" style="position:relative;">
# <div style="float:left"><h1> Capstone Project: Diabetes risk predictor based on health indicators</h1></div>
# <div style="float:left"><h2> Notebook 2: # Exploratory Data Analysis - Created by Diego Villanueva</h2></div>
# </div>
# </div>

# %% [markdown]
# This notebook is ...

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# << Place holder >>

# %% [markdown]
# ### Imports

# %%
# data manipulation
import numpy as np
import pandas as pd

# plotting
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read csv file and provide overview of data

# %%
# Load csv file
df_raw= pd.read_csv("../Data/Raw data/Diabetes_Health_Indicators_Raw.csv")

# %% [markdown]
# # Exploratory Data Analysis
# After cleaning the raw data, I will proceed with analysing the different columns in the dataframe.

# %%
df_cleaned.describe()
# Out:
#         Diabetes_012         HighBP       HighChol      CholCheck  \
# count  229781.000000  229781.000000  229781.000000  229781.000000
# mean        0.325627       0.454441       0.441760       0.959535
# std         0.724623       0.497921       0.496598       0.197047
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       1.000000
# 50%         0.000000       0.000000       0.000000       1.000000
# 75%         0.000000       1.000000       1.000000       1.000000
# max         2.000000       1.000000       1.000000       1.000000
#
#                 BMI         Smoker         Stroke  HeartDiseaseorAttack  \
# count  229781.00000  229781.000000  229781.000000         229781.000000
# mean       28.68567       0.465661       0.044756              0.103216
# std         6.78636       0.498821       0.206767              0.304241
# min        12.00000       0.000000       0.000000              0.000000
# ...

# %%
df_cleaned

# %% [markdown]
# ### Target variable
# The target variable is the Diabetes_012 column. As shown in the results below, there are 3 possible answers values found:
# * 0 -> When the person interviewed does not have diabetes or prediabetes
# * 1 -> When the person interviewed has prediabetes
# * 2 -> When the person interviewed has diabetes
#
# There are no missing values in this column.

# %% [markdown]
#  <placeholder for data dictionary >
