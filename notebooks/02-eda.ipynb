# %% [markdown]
# <div id="container" style="position:relative;">
# <div style="float:left"><h1> Capstone Project: Diabetes risk predictor based on health indicators</h1></div>
# <div style="float:left"><h2> Notebook 2: # Exploratory Data Analysis - Created by Diego Villanueva</h2></div>
# </div>
# </div>

# %% [markdown]
# ### Updated Data Dictionary

# %% [markdown]
# <table>
#     <tr>
#         <th>Column</th>
#         <th>Data Type</th>
#         <th>Description</th>
#         <th>Possible values</th>
#     </tr>
#     <tr>
#         <td>TARGET VARIABLE: Has_diabetes</td>
#         <td>float64</td>
#         <td>Does the participant have diabetes or prediabetes</td>
#         <td>0 = no diabetes 1 = prediabetes 2 = diabetes</td>
#     </tr>
#     <tr>
#         <td>Has_high_bp</td>
#         <td>float64</td>
#         <td>Has the participant being told by a medical professional that they have high blood pressure</td>
#         <td>0 = no high BP 1 = high BP</td>
#     </tr>
#     <tr>
#         <td>Has_high_cholesterol</td>
#         <td>float64</td>
#         <td>Has the participant being told by a medical professional that they have high blood cholesterol</td>
#         <td>0 = no high cholesterol 1 = high cholesterol</td>
#     </tr>
#     <tr>
#         <td>Checked_cholesterol</td>
#         <td>float64</td>
#         <td>Has the participant cholesterol been checked in the last 5 years</td>
#         <td>0 = no cholesterol check in 5 years 1 = yes cholesterol check in 5 years</td>
#     </tr>
#     <tr>
#         <td>BMI</td>
#         <td>float64</td>
#         <td>The Body Mass Index (BMI) of the participant</td>
#         <td>Any number from 12 to 98</td>
#     </tr>
#     <tr>
#         <td>Is_smoker</td>
#         <td>float64</td>
#         <td>Has the participant smoked at least 100 cigarretes in their entire life</td>
#         <td>0 = no 1 = yes</td>
#     </tr>
#     <tr>
#         <td>Had_stroke</td>
#         <td>float64</td>
#         <td>Has the participant ever had a stroke</td>
#         <td>0 = no 1 = yes</td>
#     </tr>
#     <tr>
#         <td>Has_heart_disease</td>
#         <td>float64</td>
#         <td>Has the participant has had a Coronary Heart Disease (CHD) or myocardial infarction (MI)</td>
#         <td>0 = no 1 = yes</td>
#     </tr>
#     <tr>
#         <td>Physical_activity</td>
#         <td>float64</td>
#         <td>Has the participant done any physical activity in past 30 days</td>
#         <td>0 = no 1 = yes</td>
#     </tr>
#     <tr>
#         <td>Eats_fruits</td>
#         <td>float64</td>
#         <td>Does the participant consume at least 1 fruit per day</td>
#         <td>0 = no 1 = yes</td>
#     </tr>
#     <tr>
#         <td>Eats_veggies</td>
#         <td>float64</td>
#         <td>Does the participant consume vegetables at least once per day</td>
#         <td>0 = no 1 = yes</td>
#     </tr>
#     <tr>
#         <td>Heavy_drinker</td>
#         <td>float64</td>
#         <td>Does the participant consume 14 drinks or more per week if they are an adult male, or 7 drinks or more per week if they are an adult female</td>
#         <td>0 = no 1 = yes</td>
#     </tr>
#     <tr>
#         <td>Has_healthcare_cov</td>
#         <td>float64</td>
#         <td>Does the participant have any kind of health care coverage (e.g., health insurance, prepaid plans)</td>
#         <td>0 = no 1 = yes</td>
#     </tr>
#     <tr>
#         <td>No_attention_bc_cost</td>
#         <td>float64</td>
#         <td>Has the participant had the need to to see a doctor in the past 12 months but could not do it because of financial reasons?</td>
#         <td>0 = no 1 = yes</td>
#     </tr>
#     <tr>
#         <td>General_health_score</td>
#         <td>float64</td>
#         <td>How does the participant describe their health levels on a scale from 1 to 5 </td>
#         <td>1 = excellent 2 = very good 3 = good 4 = fair 5 = poor</td>
#     </tr>
#     <tr>
#         <td>Mental_health_bad_days</td>
#         <td>float64</td>
#         <td>How many days of bad mental health has the participant had in the last 30 days</td>
#         <td>1 to 30</td>
#     </tr>
#     <tr>
#         <td>Physical_health_bad_days</td>
#         <td>float64</td>
#         <td>How many days has the participant experienced physical illness or an injury in the last 30 days</td>
#         <td>1 to 30</td>
#     </tr>
#     <tr>
#         <td>Walking_difficulty</td>
#         <td>float64</td>
#         <td>Does the participant have serious difficulty walking or climbing stairs</td>
#         <td>0 = no 1 = yes</td>
#     </tr>
#     <tr>
#         <td>Is_male</td>
#         <td>float64</td>
#         <td>What gender was the participant assigned at birth </td>
#         <td>0 = female 1 = male</td>
#     </tr>
#     <tr>
#         <td>Age</td>
#         <td>float64</td>
#         <td>Group age of the participant</td>
#         <td>1 to 13: 1 = 18 to 24, 2 = 25 to 29, 3 = 30 to 34, 4 = 35 to 39, 5 = 40 to 44, 6 = 45 to 49, 7 = 50 to 54, 8 = 55 to 59, 9 = 60 to 64, 10 = 65 to 69, 11 = 70 to 74, 12 = 75 to 79, 13 = 80+</td>
#     </tr>
#     <tr>
#         <td>Education</td>
#         <td>float64</td>
#         <td>The maximum level of education of the participant. Grouped in 6 different education levels.</td>
#         <td>1 = Never attended school or only kindergarten, 2 = Elementary education, 3 = Some high school, 4 = High school graduate, 5 = College 1 year to 3 years,  6 = College graduate and above</td>
#     </tr>
#     <tr>
#         <td>Income</td>
#         <td>float64</td>
#         <td>Desc</td>
#         <td>1 to 8: 1 = less than 10,000, 2 = 10,001 to 20,000, 3 = 20,001 to 30,000, 4 = 30,001 to 40,000, 5 = 40,001 to 50,000, 6 = 50,001 to 60,000, 7 = 60,001 to 70,000, 8 = 70,001 or more </td>
#     </tr>
# </table>

# %% [markdown]
# ### Imports

# %%
# data manipulation
import numpy as np
import pandas as pd

# plotting
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Read csv file and provide overview of data

# %%
# Load csv file
df_cleaned= pd.read_csv("../Data/Cleaned data/Diabetes_Health_Indicators_Cleaned_.csv")

# %% [markdown]
# ## Exploring data

# %%
df_cleaned.describe().T
# Out:
#                              count       mean       std   min   25%   50%  \
# Has_diabetes              253680.0   0.296921  0.698160   0.0   0.0   0.0
# Has_high_bp               253680.0   0.429001  0.494934   0.0   0.0   0.0
# Has_high_cholesterol      253680.0   0.424121  0.494210   0.0   0.0   0.0
# Checked_cholesterol       253680.0   0.962670  0.189571   0.0   1.0   1.0
# BMI                       253680.0  28.382364  6.608694  12.0  24.0  27.0
# Is_smoker                 253680.0   0.443169  0.496761   0.0   0.0   0.0
# Had_stroke                253680.0   0.040571  0.197294   0.0   0.0   0.0
# Has_heart_disease         253680.0   0.094186  0.292087   0.0   0.0   0.0
# Physical_activity         253680.0   0.756544  0.429169   0.0   1.0   1.0
# Eats_fruits               253680.0   0.634256  0.481639   0.0   0.0   1.0
# Eats_veggies              253680.0   0.811420  0.391175   0.0   1.0   1.0
# Heavy_drinker             253680.0   0.056197  0.230302   0.0   0.0   0.0
# ...

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253680 entries, 0 to 253679
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Has_diabetes              253680 non-null  float64
#  1   Has_high_bp               253680 non-null  float64
#  2   Has_high_cholesterol      253680 non-null  float64
#  3   Checked_cholesterol       253680 non-null  float64
#  4   BMI                       253680 non-null  float64
#  5   Is_smoker                 253680 non-null  float64
#  6   Had_stroke                253680 non-null  float64
#  7   Has_heart_disease         253680 non-null  float64
#  8   Physical_activity         253680 non-null  float64
#  9   Eats_fruits               253680 non-null  float64
#  10  Eats_veggies              253680 non-null  float64
#  11  Heavy_drinker             253680 non-null  float64
#  12  Has_healthcare_cov        253680 non-null  float64
# ...

# %% [markdown]
# ### Target variable
# The target variable is the Has_diabetes column. As shown in the results below, there are 3 possible answer values found:
# * 0 -> When the person interviewed does not have diabetes or prediabetes
# * 1 -> When the person interviewed has prediabetes
# * 2 -> When the person interviewed has diabetes
#
# Based on initial observations, 84% of the participants do not have diabetes or prediabetes, 14% have diabetes, and 1% have prediabetes.
#
# There are no missing values in this column.

# %%
Has_diabetes_counts = df_cleaned['Has_diabetes'].value_counts()
percentages = (Has_diabetes_counts / len(df_cleaned['Has_diabetes'])) * 100
print(percentages)
# Out:
# Has_diabetes
# 0.0    84.241170
# 2.0    13.933302
# 1.0     1.825528
# Name: count, dtype: float64

# %% [markdown]
# ### Univariate analysis of all columns

# %%
# Create lists of which columns are categorical and which ones continous
non_categorical_features = ['BMI', 'Mental_health_bad_days', 'Physical_health_bad_days']
categorical_features = [col for col in df_cleaned.columns if col not in continous_features]
print(categorical_features)
# Out:
# ['Has_diabetes', 'Has_high_bp', 'Has_high_cholesterol', 'Checked_cholesterol', 'Is_smoker', 'Had_stroke', 'Has_heart_disease', 'Physical_activity', 'Eats_fruits', 'Eats_veggies', 'Heavy_drinker', 'Has_healthcare_cov', 'No_attention_bc_cost', 'General_health_score', 'Walking_difficulty', 'Is_male', 'Age', 'Education', 'Income']

# %%
# Set up grid of subplots
plt.subplots(1, len(non_categorical_features), figsize=(15, 5))

# Initialize count
plot_num = 1

# Loop through column names in the list of continuous features
for i in non_categorical_features:
    # Save column values, mean, and median to variables
    values_temp = df_cleaned[i]
    mean_temp = values_temp.mean()
    median_temp = values_temp.median()

    # Plot a histogram of the continuous feature, with lines marking mean and median
    plt.subplot(1, len(non_categorical_features), plot_num)
    sns.histplot(values_temp)
    plt.axvline(mean_temp, color='r', label='Mean')
    plt.axvline(median_temp, color='g', label='Median')
    plt.title(f'{i}')
    plt.legend()

    plot_num += 1

plt.tight_layout()
plt.show()

# %%
# Define the number of rows and columns for the subplot grid
num_rows = 8  # You can adjust this based on your preference
num_cols = 3  # You can adjust this based on your preference
total_plots = num_rows * num_cols

# Create a new figure with subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(16, 16))

# Flatten the 2D array of subplots into a 1D array
axes = axes.flatten()

# Loop through columns 1 to the last column (excluding the first column)
for i, column in enumerate(df_cleaned.columns[1:], start=1):
    ax = axes[i - 1]

    # Create a stacked bar chart
    df_cleaned.groupby(['Has_diabetes', column]).size().unstack().plot(kind='bar', stacked=True, ax=ax)

    # Set labels and title
    ax.set_xlabel('Has_diabetes')
    ax.set_ylabel('Count')
    ax.set_title(f'Stacked Bar Chart for {column}')

# Remove any empty subplots
for i in range(len(df_cleaned.columns) - 1, total_plots):
    fig.delaxes(axes[i])

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /var/folders/6c/0s0k1hv53xn7g3bpzkggst1r0000gn/T/ipykernel_97721/2113061568.py:29: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# #### Observations:
#
# < placeholder>

# %% [markdown]
# ### Bivariate Analysis

# %%
# Create variables for possible predictive columns and target variable
# x_options=list(df_cleaned.select_dtypes(include='float'))
x_options=list(df_cleaned.drop(columns="Has_diabetes").select_dtypes(include='float'))
y=df_cleaned['Has_diabetes']

# %%
# Create visualisations to show relationship between target variable and possible features
plt.subplots(11,2,figsize=(15,15))

plot_num=1

plt.suptitle("Relationship between someone's diabetes status and their other characteristics", fontsize=16)

for col in x_options:

    plt.subplot(11,2,plot_num)
    sns.scatterplot(x=df_cleaned[col],y=y, alpha=0.01)
    plt.title(f'Has Diabetes vs {col}')

    plot_num+=1

plt.subplots_adjust(top=0.93)

plt.show()

# %% [markdown]
# NOTE: use stacked charts, first with variables comparing to the target variable, and then
# with each categorical variable showing the proportion of answers from them.
#
# https://www.google.com/search?sca_esv=574389216&rlz=1C5CHFA_enAU731AU731&q=how+to+visualize+categorical+against+categorical+variables+relationship&tbm=isch&source=lnms&sa=X&ved=2ahUKEwifr9-jnP-BAxUO_rsIHSNZBdUQ0pQJegQIDBAB&biw=1440&bih=783&dpr=2#imgrc=NKCo9EYa8ikpZM&imgdii=xXejOtikGo2lZM

# %% [markdown]
# #### Observations
#
# <placeholder>

# %% [markdown]
# ### Correlations between variables

# %%
# Generate a correlation matrix
df_cleaned.corr()
# Out:
#                           Has_diabetes  Has_high_bp  Has_high_cholesterol  \
# Has_diabetes                  1.000000     0.271596              0.209085
# Has_high_bp                   0.271596     1.000000              0.298199
# Has_high_cholesterol          0.209085     0.298199              1.000000
# Checked_cholesterol           0.067546     0.098508              0.085642
# BMI                           0.224379     0.213748              0.106722
# Is_smoker                     0.062914     0.096991              0.091299
# Had_stroke                    0.107179     0.129575              0.092620
# Has_heart_disease             0.180272     0.209361              0.180765
# Physical_activity            -0.121947    -0.125267             -0.078046
# Eats_fruits                  -0.042192    -0.040555             -0.040859
# Eats_veggies                 -0.058972    -0.061266             -0.039874
# Heavy_drinker                -0.057882    -0.003972             -0.011543
# ...

# %%
# Plot the correlation matrix as a heatmap to make it more readable

# mask for upper-triangle
mask = np.triu(df_cleaned.corr())

plt.figure(figsize=(15, 15))
sns.heatmap(df_cleaned.corr(), annot=True, center=0, cmap='coolwarm', vmin=-1, vmax=1, mask=mask)
plt.show()

# %% [markdown]
# Observations:
# Based on the correlation matrix and heatmap above, we have detected multicollinearity that has to be fixed before creating the model during the next stage of the process.
# Physical_health_bad_days and General_health_score have a high correlation, with 0.52, and will need to be deleted during pre-processing

# %% [markdown]
#  <placeholder for data dictionary >
